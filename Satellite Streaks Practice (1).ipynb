# %%
#Libraries
import astropy.units as u
from astropy.time import Time
from astropy.coordinates import EarthLocation
import matplotlib.pyplot as plt
import numpy as np
import requests
from astropy.coordinates import SkyCoord
from astropy.wcs import WCS
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
from matplotlib.patches import Polygon
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default = "notebook"
import pandas as pd

from tqdm import tqdm
import requests

# %% [markdown]
# ### Import the DECam telemetry and streaks datasets

# %%
telemetry1 = pd.read_csv('decam_telemetry_20230817.csv.gz')

# %%
telemetry1
# Out:
#          EXPNUM BAND              TELESCOP OBSERVAT INSTRUME  OBS-LONG  \
# 0        140520    r  CTIO 4.0-m telescope     CTIO    DECam   70.8149
# 1        140521    r  CTIO 4.0-m telescope     CTIO    DECam   70.8149
# 2        140522    u  CTIO 4.0-m telescope     CTIO    DECam   70.8149
# 3        140523    u  CTIO 4.0-m telescope     CTIO    DECam   70.8149
# 4        140524    u  CTIO 4.0-m telescope     CTIO    DECam   70.8149
# ...         ...  ...                   ...      ...      ...       ...
# 506513  1228730    g  CTIO 4.0-m telescope     CTIO    DECam   70.8149
# 506514  1228731    r  CTIO 4.0-m telescope     CTIO    DECam   70.8149
# 506515  1228732    r  CTIO 4.0-m telescope     CTIO    DECam   70.8149
# 506516  1228733    i  CTIO 4.0-m telescope     CTIO    DECam   70.8149
# 506517  1228734    i  CTIO 4.0-m telescope     CTIO    DECam   70.8149
#
#         OBS-LAT  OBS-ELEV  TELEQUIN TIMESYS                    DATE-OBS  \
# 0      -30.1661      2215      2000     UTC  2012-10-20 00:25:35.429106
# 1      -30.1661      2215      2000     UTC  2012-10-20 00:29:50.667562
# 2      -30.1661      2215      2000     UTC  2012-10-20 00:46:16.576959
# 3      -30.1661      2215      2000     UTC  2012-10-20 00:47:44.370016
# 4      -30.1661      2215      2000     UTC  2012-10-20 00:49:47.211636
# ...         ...       ...       ...     ...                         ...
# 506513 -30.1661      2215      2000     UTC  2023-08-03 08:42:53.917964
# 506514 -30.1661      2215      2000     UTC  2023-08-03 08:44:44.058111
# 506515 -30.1661      2215      2000     UTC  2023-08-03 08:46:22.681357
# 506516 -30.1661      2215      2000     UTC  2023-08-03 08:48:02.549261
# 506517 -30.1661      2215      2000     UTC  2023-08-03 08:50:01.864095
#
#                TIME-OBS  DARKTIME  EXPTIME            RA            DEC  \
# 0       00:25:35.429106   2.10353      1.0  22:08:24.000  -32:59:17.599
# 1       00:29:50.667562   2.09597      1.0  22:08:23.970  -32:55:57.799
# 2       00:46:16.576959  31.09820     30.0  18:03:35.240  -30:02:00.600
# 3       00:47:44.370016  31.09300     30.0  18:03:35.250  -30:02:00.802
# 4       00:49:47.211636  31.09170     30.0  18:03:35.240  -30:02:00.802
# ...                 ...       ...      ...           ...            ...
# 506513  08:42:53.917964  81.10140     80.0  03:30:36.090  -28:05:58.200
# 506514  08:44:44.058111  71.12170     70.0  03:30:36.079  -28:05:58.200
# 506515  08:46:22.681357  71.10870     70.0  03:30:36.090  -28:05:58.200
# 506516  08:48:02.549261  91.09020     90.0  03:30:36.112  -28:05:58.099
# 506517  08:50:01.864095  91.12910     90.0  03:30:36.112  -28:05:58.099
#
#               AZ     ZD
# 0       116.2500   7.09
# 1       118.9300   6.25
# 2       254.2700  50.20
# 3       254.1500  50.50
# 4       253.9900  50.93
# ...          ...    ...
# 506513   97.1620  36.05
# 506514   97.0003  35.66
# 506515   96.8515  35.30
# 506516   96.7036  34.94
# 506517   96.5253  34.52
#
# [506518 rows x 18 columns]

# %%
telemetry1.columns
# Out:
# Index(['EXPNUM', 'BAND', 'TELESCOP', 'OBSERVAT', 'INSTRUME', 'OBS-LONG',
#        'OBS-LAT', 'OBS-ELEV', 'TELEQUIN', 'TIMESYS', 'DATE-OBS', 'TIME-OBS',
#        'DARKTIME', 'EXPTIME', 'RA', 'DEC', 'AZ', 'ZD'],
#       dtype='object')

# %%
streaks1 = pd.read_csv('streaks_augmented_20230817.csv.gz')

# %%
streaks1
# Out:
#                                      filename  rnum        ra_1        ra_2  \
# 0       D00145425_g_c03_r4148p01_hstreak.fits     3    1.159330    1.160919
# 1       D00145425_g_c06_r4148p01_hstreak.fits     1    0.986677    0.986711
# 2       D00145425_g_c09_r4148p01_hstreak.fits     1    0.452852    0.452942
# 3       D00145425_g_c15_r4148p01_hstreak.fits     1    0.286716    0.286812
# 4       D00145425_g_c16_r4148p01_hstreak.fits     1    0.985852    0.987446
# ...                                       ...   ...         ...         ...
# 879115  D01223535_g_c05_r6224p01_hstreak.fits     1  323.500201  323.502653
# 879116  D01223535_g_c31_r6224p01_hstreak.fits     1  324.355544  324.369908
# 879117  D01223535_g_c56_r6224p01_hstreak.fits     1  322.914589  322.934330
# 879118  D01223535_g_c58_r6224p01_hstreak.fits     1  323.771850  323.783894
# 879119  D01223535_g_c59_r6224p01_hstreak.fits     1  323.878330  323.890982
#
#               ra_3        ra_4      dec_1      dec_2      dec_3      dec_4  \
# 0         1.164310    1.162720 -28.724241 -28.724212 -28.857155 -28.857183
# 1         0.644209    0.644186 -29.032018 -29.034283 -29.037208 -29.034944
# 2         0.109842    0.109782 -29.193042 -29.199694 -29.203265 -29.196615
# 3         0.630816    0.630741 -29.363308 -29.358405 -29.362739 -29.367644
# 4         0.987211    0.985615 -29.216748 -29.216752 -29.366385 -29.366381
# ...            ...         ...        ...        ...        ...        ...
# 879115  323.444690  323.442238 -17.828499 -17.830897 -17.884254 -17.881855
# 879116  324.372363  324.357994 -18.392109 -18.391941 -18.541070 -18.541235
# 879117  322.849385  322.829651 -19.193809 -19.210870 -19.298406 -19.281342
# 879118  323.835739  323.823696 -19.214779 -19.204086 -19.255903 -19.266598
# 879119  323.836373  323.823717 -19.203540 -19.214870 -19.269001 -19.257671
#
#          expnum  ccdnum band
# 0        145425       3    g
# 1        145425       6    g
# 2        145425       9    g
# 3        145425      15    g
# 4        145425      16    g
# ...         ...     ...  ...
# 879115  1223535       5    g
# 879116  1223535      31    g
# 879117  1223535      56    g
# 879118  1223535      58    g
# 879119  1223535      59    g
#
# [879120 rows x 13 columns]

# %%
one_streak_obs = telemetry1.loc[(telemetry1['EXPNUM'] == 1215959)]
one_streak= streaks1.loc[(streaks1['expnum'] == 1215959)]

# %%
one_streak_obs
one_streak
# Out:
#                                      filename  rnum        ra_1        ra_2  \
# 873910  D01215959_g_c08_r6186p01_hstreak.fits     1  241.257974  241.258527
# 873911   D01215959_g_c09_r6186p01_streak.fits     1  241.568012  241.568570
# 873912   D01215959_g_c10_r6186p01_streak.fits     1  241.878716  241.879267
# 873913   D01215959_g_c15_r6186p01_streak.fits     1  241.723504  241.723504
# 873914  D01215959_g_c16_r6186p01_hstreak.fits     1  242.034305  242.034869
# 873915  D01215959_g_c17_r6186p01_hstreak.fits     1  242.345188  242.345908
# 873916  D01215959_g_c18_r6186p01_hstreak.fits     1  242.656128  242.656653
# 873917   D01215959_g_c28_r6186p01_streak.fits     1  241.877015  241.877759
# 873918   D01215959_g_c29_r6186p01_streak.fits     1  242.188104  242.188846
# 873919  D01215959_g_c36_r6186p01_hstreak.fits     1  242.258599  242.259336
# 873920  D01215959_g_c37_r6186p01_hstreak.fits     1  242.498699  242.499719
# 873921  D01215959_g_c44_r6186p01_hstreak.fits     1  242.771301  242.772033
#
#               ra_3        ra_4     dec_1     dec_2     dec_3     dec_4  \
# 873910  241.557765  241.557210 -2.124728 -2.120690 -2.160848 -2.164887
# 873911  241.868458  241.867904 -2.166502 -2.162458 -2.202872 -2.206918
# 873912  241.923898  241.923348 -2.208372 -2.204326 -2.210327 -2.214373
# 873913  241.723504  241.723504 -2.224225 -2.224225 -2.224225 -2.224225
# 873914  242.334990  242.334432 -2.228388 -2.224345 -2.266120 -2.270164
# 873915  242.645713  242.644999 -2.272760 -2.266976 -2.304862 -2.310644
# 873916  242.955710  242.955184 -2.312570 -2.308527 -2.348197 -2.352238
# 873917  242.178449  242.177706 -2.596740 -2.594459 -2.692230 -2.694512
# 873918  242.219537  242.218794 -2.697890 -2.695607 -2.705575 -2.707858
# 873919  242.488681  242.487945 -2.720983 -2.718699 -2.792626 -2.794908
# 873920  242.730331  242.729313 -2.798843 -2.795727 -2.871101 -2.874214
# 873921  242.953787  242.953055 -2.887202 -2.884920 -2.943217 -2.945498
#
#          expnum  ccdnum band
# 873910  1215959       8    g
# 873911  1215959       9    g
# 873912  1215959      10    g
# 873913  1215959      15    g
# 873914  1215959      16    g
# 873915  1215959      17    g
# 873916  1215959      18    g
# 873917  1215959      28    g
# 873918  1215959      29    g
# 873919  1215959      36    g
# 873920  1215959      37    g
# 873921  1215959      44    g

# %%
fov_radius = 1  # degree radius for the satchecker query
location = EarthLocation.of_site('ctio')
latitude = location.lat.value  # deg
longitude = location.lon.value  # deg
elevation = location.height.value  # meters

# %%
duration = one_streak_obs['EXPTIME'].values[0]
start_time_jd = Time(one_streak_obs['DATE-OBS'].values[0]).jd

# %%
coord = SkyCoord(ra=one_streak_obs['RA'].values[0], dec=one_streak_obs['DEC'].values[0], unit=u.deg)

# %%
ra_center = coord.icrs.ra.value
dec_center = coord.icrs.dec.value

# %%
# Make the SatChecker API request
url_string = f"https://dev.satchecker.cps.iau.noirlab.edu/fov/satellite-passes/?latitude={latitude}&longitude={longitude}&elevation={elevation}&start_time_jd={start_time_jd}&duration={duration}&ra={ra_center}&dec={dec_center}&fov_radius={fov_radius}&group_by=satellite"
response = requests.get(url_string, timeout=60)
data = response.json()
print(url_string)
# Out:
# https://dev.satchecker.cps.iau.noirlab.edu/fov/satellite-passes/?latitude=-30.165277777777778&longitude=-70.815&elevation=2214.9999999993697&start_time_jd=2460114.654639777&duration=200.0&ra=16.13495&dec=-2.715333055555556&fov_radius=1&group_by=satellite

# %%
# Extract RA/Dec positions for each satellite
satellites = {}

for sat_key, sat_data in data['data']['satellites'].items():
    if sat_key not in satellites:
        satellites[sat_key] = []
    # Add ra, dec, and julian_date from each position
    for position in sat_data['positions']:
        satellites[sat_key].append([
            position['ra'],
            position['dec'],
            position['julian_date']
        ])

print(f"Public catalog satellites passing through the specified FOV, as seen from CTIO, starting at {start_time_jd} JD for {duration} seconds:")
for sat in satellites:
    print(f"{sat}: {len(satellites[sat])} points")
# Out:
# Public catalog satellites passing through the specified FOV, as seen from CTIO, starting at 2460114.654639777 JD for 200.0 seconds:
# ORBCOMM FM 23 (25477): 37 points
# ORBCOMM FM 27 (25481): 28 points
# SOCRAT (44414): 7 points
# STARLINK-1833 (46759): 2 points
# STARLINK-3843 (52341): 34 points
# YAOGAN-35 05B (53761): 47 points

# %%
# Simple WCS for the plot
wcs = WCS(naxis=2)
wcs.wcs.crpix = [0, 0]
wcs.wcs.crval = [ra_center, dec_center]
wcs.wcs.cdelt = [0.1, 0.1]
wcs.wcs.ctype = ['RA---TAN', 'DEC--TAN']

fig = plt.figure(figsize=(14,10))
ax = fig.add_subplot(1, 1, 1, projection=wcs)
center = SkyCoord(ra=ra_center*u.deg, dec=dec_center*u.deg, frame='icrs')
position_angles = np.linspace(0, 360, 360) * u.deg
circle_points = center.directional_offset_by(position_angles, fov_radius * u.deg)

# Query FOV
ax.plot(circle_points.ra.deg, circle_points.dec.deg, 
        c='0.75', ls='--', label='Query FOV', transform=ax.get_transform('world'))

# Satellite tracks
for sat_name in satellites.keys():
    ra = [pos[0] for pos in satellites[sat_name]]
    dec = [pos[1] for pos in satellites[sat_name]]
    coords = SkyCoord(ra=ra*u.deg, dec=dec*u.deg)
    
    # Satellite track
    ax.plot(coords.ra.deg, coords.dec.deg, 
            transform=ax.get_transform('world'),
            label=sat_name)
        
    # Satellite position points
    ax.scatter(coords.ra.deg, coords.dec.deg, 
               transform=ax.get_transform('world'), s=6)
    
    # Start and end labels
    times = [pos[2] for pos in satellites[sat_name]]
    if coords.ra.deg[0] < coords.ra.deg[-1]:
        ax.text(coords.ra.deg[0], coords.dec.deg[0], f'{sat_name}', 
                transform=ax.get_transform('world'), fontsize="6")  
    else:
        ax.text(coords.ra.deg[-1], coords.dec.deg[-1], f'{sat_name}', 
            transform=ax.get_transform('world'), fontsize="6")

ax.set_aspect('equal')
ax.legend(bbox_to_anchor=(0.95, 1), loc='upper left', fontsize="6")
ax.set_xlabel('Right Ascension')
ax.invert_xaxis()
ax.set_ylabel('Declination')
ax.set_title(f'Satellite Passes at {start_time_jd} (duration {duration:.1f})')
ax.grid(color='lightgray', linestyle='--')

# %% [markdown]
# ### Random exposure
# What if I choose a random exposure of the dataset?

# %%
random_exposure = telemetry1.sample()
random_exposure_num = random_exposure['EXPNUM'].values[0]
random_exposure_num
# Out:
# 997244

# %%
rand_streak_obs = telemetry1.loc[(telemetry1['EXPNUM'] == random_exposure_num)]

# %%
rand_streak_obs
# Out:
#         EXPNUM BAND              TELESCOP OBSERVAT INSTRUME  OBS-LONG  \
# 421875  997244    z  CTIO 4.0-m telescope     CTIO    DECam   70.8149
#
#         OBS-LAT  OBS-ELEV  TELEQUIN TIMESYS                    DATE-OBS  \
# 421875 -30.1661      2215      2000     UTC  2021-05-14 23:00:41.019872
#
#                TIME-OBS  DARKTIME  EXPTIME            RA            DEC  \
# 421875  23:00:41.019872    6.2069      5.0  05:32:01.770  -21:51:18.799
#
#               AZ    ZD
# 421875  262.0477  57.3

# %% [markdown]
# And then I just repeat the plot process...

# %%
fov_radius = 1  # degree radius for the satchecker query
location = EarthLocation.of_site('ctio')
latitude = location.lat.value  # deg
longitude = location.lon.value  # deg
elevation = location.height.value  # meters

duration = rand_streak_obs['EXPTIME'].values[0]
start_time_jd = Time(rand_streak_obs['DATE-OBS'].values[0]).jd

coord = SkyCoord(ra=rand_streak_obs['RA'].values[0], dec=rand_streak_obs['DEC'].values[0], unit=u.deg)
ra_center = coord.icrs.ra.value
dec_center = coord.icrs.dec.value

# %%
# Make the SatChecker API request
url_string = f"https://dev.satchecker.cps.iau.noirlab.edu/fov/satellite-passes/?latitude={latitude}&longitude={longitude}&elevation={elevation}&start_time_jd={start_time_jd}&duration={duration}&ra={ra_center}&dec={dec_center}&fov_radius={fov_radius}&group_by=satellite"
response = requests.get(url_string, timeout=60)
data = response.json()
print(url_string)
# Out:
# https://dev.satchecker.cps.iau.noirlab.edu/fov/satellite-passes/?latitude=-30.165277777777778&longitude=-70.815&elevation=2214.9999999993697&start_time_jd=2459349.4588081003&duration=5.0&ra=5.533825&dec=-21.855221944444445&fov_radius=1&group_by=satellite

# %%
# Extract RA/Dec positions for each satellite
satellites = {}

for sat_key, sat_data in data['data']['satellites'].items():
    if sat_key not in satellites:
        satellites[sat_key] = []
    # Add ra, dec, and julian_date from each position
    for position in sat_data['positions']:
        satellites[sat_key].append([
            position['ra'],
            position['dec'],
            position['julian_date']
        ])

print(f"Public catalog satellites passing through the specified FOV, as seen from CTIO, starting at {start_time_jd} JD for {duration} seconds:")
for sat in satellites:
    print(f"{sat}: {len(satellites[sat])} points")
# Out:
# Public catalog satellites passing through the specified FOV, as seen from CTIO, starting at 2459349.4588081003 JD for 5.0 seconds:
# SL-8 R/B (11751): 6 points

# %%
# Simple WCS for the plot
wcs = WCS(naxis=2)
wcs.wcs.crpix = [0, 0]
wcs.wcs.crval = [ra_center, dec_center]
wcs.wcs.cdelt = [0.1, 0.1]
wcs.wcs.ctype = ['RA---TAN', 'DEC--TAN']

fig = plt.figure(figsize=(14,10))
ax = fig.add_subplot(1, 1, 1, projection=wcs)
center = SkyCoord(ra=ra_center*u.deg, dec=dec_center*u.deg, frame='icrs')
position_angles = np.linspace(0, 360, 360) * u.deg
circle_points = center.directional_offset_by(position_angles, fov_radius * u.deg)

# Query FOV
ax.plot(circle_points.ra.deg, circle_points.dec.deg, 
        c='0.75', ls='--', label='Query FOV', transform=ax.get_transform('world'))

# Satellite tracks
for sat_name in satellites.keys():
    ra = [pos[0] for pos in satellites[sat_name]]
    dec = [pos[1] for pos in satellites[sat_name]]
    coords = SkyCoord(ra=ra*u.deg, dec=dec*u.deg)
    
    # Satellite track
    ax.plot(coords.ra.deg, coords.dec.deg, 
            transform=ax.get_transform('world'),
            label=sat_name)
        
    # Satellite position points
    ax.scatter(coords.ra.deg, coords.dec.deg, 
               transform=ax.get_transform('world'), s=6)
    
    # Start and end labels
    times = [pos[2] for pos in satellites[sat_name]]
    if coords.ra.deg[0] < coords.ra.deg[-1]:
        ax.text(coords.ra.deg[0], coords.dec.deg[0], f'{sat_name}', 
                transform=ax.get_transform('world'), fontsize="6")  
    else:
        ax.text(coords.ra.deg[-1], coords.dec.deg[-1], f'{sat_name}', 
            transform=ax.get_transform('world'), fontsize="6")

ax.set_aspect('equal')
ax.legend(bbox_to_anchor=(0.95, 1), loc='upper left', fontsize="6")
ax.set_xlabel('Right Ascension')
ax.invert_xaxis()
ax.set_ylabel('Declination')
ax.set_title(f'Satellite Passes at {start_time_jd} (duration {duration:.1f})')
ax.grid(color='lightgray', linestyle='--')

# %% [markdown]
# ### More than 8 streaks

# %% [markdown]
# To identify that exposures that appear more than 8 times at the dataset (more than 8 streaks), we can select them

# %%
streaks1
# Out:
#                                      filename  rnum        ra_1        ra_2  \
# 0       D00145425_g_c03_r4148p01_hstreak.fits     3    1.159330    1.160919
# 1       D00145425_g_c06_r4148p01_hstreak.fits     1    0.986677    0.986711
# 2       D00145425_g_c09_r4148p01_hstreak.fits     1    0.452852    0.452942
# 3       D00145425_g_c15_r4148p01_hstreak.fits     1    0.286716    0.286812
# 4       D00145425_g_c16_r4148p01_hstreak.fits     1    0.985852    0.987446
# ...                                       ...   ...         ...         ...
# 879115  D01223535_g_c05_r6224p01_hstreak.fits     1  323.500201  323.502653
# 879116  D01223535_g_c31_r6224p01_hstreak.fits     1  324.355544  324.369908
# 879117  D01223535_g_c56_r6224p01_hstreak.fits     1  322.914589  322.934330
# 879118  D01223535_g_c58_r6224p01_hstreak.fits     1  323.771850  323.783894
# 879119  D01223535_g_c59_r6224p01_hstreak.fits     1  323.878330  323.890982
#
#               ra_3        ra_4      dec_1      dec_2      dec_3      dec_4  \
# 0         1.164310    1.162720 -28.724241 -28.724212 -28.857155 -28.857183
# 1         0.644209    0.644186 -29.032018 -29.034283 -29.037208 -29.034944
# 2         0.109842    0.109782 -29.193042 -29.199694 -29.203265 -29.196615
# 3         0.630816    0.630741 -29.363308 -29.358405 -29.362739 -29.367644
# 4         0.987211    0.985615 -29.216748 -29.216752 -29.366385 -29.366381
# ...            ...         ...        ...        ...        ...        ...
# 879115  323.444690  323.442238 -17.828499 -17.830897 -17.884254 -17.881855
# 879116  324.372363  324.357994 -18.392109 -18.391941 -18.541070 -18.541235
# 879117  322.849385  322.829651 -19.193809 -19.210870 -19.298406 -19.281342
# 879118  323.835739  323.823696 -19.214779 -19.204086 -19.255903 -19.266598
# 879119  323.836373  323.823717 -19.203540 -19.214870 -19.269001 -19.257671
#
#          expnum  ccdnum band
# 0        145425       3    g
# 1        145425       6    g
# 2        145425       9    g
# 3        145425      15    g
# 4        145425      16    g
# ...         ...     ...  ...
# 879115  1223535       5    g
# 879116  1223535      31    g
# 879117  1223535      56    g
# 879118  1223535      58    g
# 879119  1223535      59    g
#
# [879120 rows x 13 columns]

# %%
expnum_counts = streaks1['expnum'].value_counts()
expnums_mas_8 = expnum_counts[expnum_counts > 8].index
streaks_filtradas = streaks1[streaks1['expnum'].isin(expnums_mas_8)]

# %%
streaks_filtradas
# Out:
#                                      filename  rnum        ra_1        ra_2  \
# 0       D00145425_g_c03_r4148p01_hstreak.fits     3    1.159330    1.160919
# 1       D00145425_g_c06_r4148p01_hstreak.fits     1    0.986677    0.986711
# 2       D00145425_g_c09_r4148p01_hstreak.fits     1    0.452852    0.452942
# 3       D00145425_g_c15_r4148p01_hstreak.fits     1    0.286716    0.286812
# 4       D00145425_g_c16_r4148p01_hstreak.fits     1    0.985852    0.987446
# ...                                       ...   ...         ...         ...
# 879102  D01223533_g_c21_r6224p01_hstreak.fits     1  322.350759  322.367974
# 879103  D01223533_g_c27_r6224p01_hstreak.fits     1  321.914442  321.929370
# 879104  D01223533_g_c33_r6224p01_hstreak.fits     2  321.914515  321.920861
# 879105  D01223533_g_c44_r6224p01_hstreak.fits     1  323.071804  323.087515
# 879106  D01223533_g_c54_r6224p01_hstreak.fits     1  322.679468  322.691395
#
#               ra_3        ra_4      dec_1      dec_2      dec_3      dec_4  \
# 0         1.164310    1.162720 -28.724241 -28.724212 -28.857155 -28.857183
# 1         0.644209    0.644186 -29.032018 -29.034283 -29.037208 -29.034944
# 2         0.109842    0.109782 -29.193042 -29.199694 -29.203265 -29.196615
# 3         0.630816    0.630741 -29.363308 -29.358405 -29.362739 -29.367644
# 4         0.987211    0.985615 -29.216748 -29.216752 -29.366385 -29.366381
# ...            ...         ...        ...        ...        ...        ...
# 879102  322.430509  322.413294 -19.778872 -19.762994 -19.822898 -19.838787
# 879103  322.039930  322.024991 -19.992600 -19.979549 -20.091439 -20.104500
# 879104  321.868432  321.862089 -20.207886 -20.214118 -20.261253 -20.255020
# 879105  323.208026  323.192338 -20.367516 -20.345896 -20.422967 -20.444584
# 879106  322.589240  322.577308 -20.592385 -20.603303 -20.700661 -20.689741
#
#          expnum  ccdnum band
# 0        145425       3    g
# 1        145425       6    g
# 2        145425       9    g
# 3        145425      15    g
# 4        145425      16    g
# ...         ...     ...  ...
# 879102  1223533      21    g
# 879103  1223533      27    g
# 879104  1223533      33    g
# 879105  1223533      44    g
# 879106  1223533      54    g
#
# [532326 rows x 13 columns]

# %%
expnum_counts[expnum_counts > 8] # How many times that exposure appear in the dataset
# Out:
# 619360     61
# 189384     61
# 646812     61
# 1150145    61
# 193580     61
#            ..
# 220686      9
# 915972      9
# 907578      9
# 420085      9
# 1069083     9
# Name: expnum, Length: 38030, dtype: int64

# %%
expnums_mas_8 = expnum_counts[expnum_counts > 8].index.tolist() # Which are those exposures that have more than 8 streaks
#print(expnums_mas_8)

# %%
len(set(expnums_mas_8))
# Out:
# 38030

# %%
lot_of_streaks = telemetry1.loc[(telemetry1['EXPNUM'] == 915972)]  # I select the first for the example, that it's supossed to have 61 streaks (that's a lot, it's possible??)
lot_of_streaks
# Out:
#         EXPNUM BAND              TELESCOP OBSERVAT INSTRUME  OBS-LONG  \
# 227761  619360    Y  CTIO 4.0-m telescope     CTIO    DECam   70.8149
#
#         OBS-LAT  OBS-ELEV  TELEQUIN TIMESYS                    DATE-OBS  \
# 227761 -30.1661      2215      2000     UTC  2017-02-11 07:18:17.857722
#
#                TIME-OBS  DARKTIME  EXPTIME            RA            DEC  \
# 227761  07:18:17.857722   151.878    150.0  06:41:31.099  -50:57:38.894
#
#               AZ     ZD
# 227761  225.2088  60.75

# %%
fov_radius = 1  # degree radius for the satchecker query
location = EarthLocation.of_site('ctio')
latitude = location.lat.value  # deg
longitude = location.lon.value  # deg
elevation = location.height.value  # meters

# %%
duration = lot_of_streaks['EXPTIME'].values[0]
start_time_jd = Time(lot_of_streaks['DATE-OBS'].values[0]).jd

# %%
coord = SkyCoord(ra=lot_of_streaks['RA'].values[0], dec=lot_of_streaks['DEC'].values[0], unit=u.deg)
ra_center = coord.icrs.ra.value
dec_center = coord.icrs.dec.value

# %%
# Make the SatChecker API request
url_string = f"https://dev.satchecker.cps.iau.noirlab.edu/fov/satellite-passes/?latitude={latitude}&longitude={longitude}&elevation={elevation}&start_time_jd={start_time_jd}&duration={duration}&ra={ra_center}&dec={dec_center}&fov_radius={fov_radius}&group_by=satellite"
response = requests.get(url_string, timeout=60)
data = response.json()
print(url_string)
# Out:
# https://dev.satchecker.cps.iau.noirlab.edu/fov/satellite-passes/?latitude=-30.165277777777778&longitude=-70.815&elevation=2214.9999999993697&start_time_jd=2457795.8043733533&duration=150.0&ra=6.691971944444445&dec=-50.96080388888889&fov_radius=1&group_by=satellite

# %%
# Extract RA/Dec positions for each satellite
satellites = {}

for sat_key, sat_data in data['data']['satellites'].items():
    if sat_key not in satellites:
        satellites[sat_key] = []
    # Add ra, dec, and julian_date from each position
    for position in sat_data['positions']:
        satellites[sat_key].append([
            position['ra'],
            position['dec'],
            position['julian_date']
        ])

print(f"Public catalog satellites passing through the specified FOV, as seen from CTIO, starting at {start_time_jd} JD for {duration} seconds:")
for sat in satellites:
    print(f"{sat}: {len(satellites[sat])} points")
# Out:
# Public catalog satellites passing through the specified FOV, as seen from CTIO, starting at 2457795.8043733533 JD for 150.0 seconds:
# COSMOS 1275 DEB (13485): 19 points
# COSMOS 158 (2801): 27 points
# COSMOS 2251 DEB (37303): 27 points
# COSMOS 2353 (25364): 45 points
# DELTA 1 DEB (17764): 15 points
# DELTA 1 DEB (21387): 17 points
# DELTA 1 DEB (7044): 7 points
# FENGYUN 1C DEB (29873): 3 points
# FENGYUN 1C DEB (31675): 22 points
# NIMBUS 2 DEB (28203): 21 points
# SL-24 R/B (28811): 7 points
# THOR ABLESTAR DEB (479): 19 points
# THORAD DELTA 1 DEB (8562): 33 points
# THORAD DELTA 1 R/B (7532): 27 points
# TIANHUI 1-03 (40988): 7 points

# %%
# Simple WCS for the plot
wcs = WCS(naxis=2)
wcs.wcs.crpix = [0, 0]
wcs.wcs.crval = [ra_center, dec_center]
wcs.wcs.cdelt = [0.1, 0.1]
wcs.wcs.ctype = ['RA---TAN', 'DEC--TAN']

fig = plt.figure(figsize=(14,10))
ax = fig.add_subplot(1, 1, 1, projection=wcs)
center = SkyCoord(ra=ra_center*u.deg, dec=dec_center*u.deg, frame='icrs')
position_angles = np.linspace(0, 360, 360) * u.deg
circle_points = center.directional_offset_by(position_angles, fov_radius * u.deg)

# Query FOV
ax.plot(circle_points.ra.deg, circle_points.dec.deg, 
        c='0.75', ls='--', label='Query FOV', transform=ax.get_transform('world'))

# Satellite tracks
for sat_name in satellites.keys():
    ra = [pos[0] for pos in satellites[sat_name]]
    dec = [pos[1] for pos in satellites[sat_name]]
    coords = SkyCoord(ra=ra*u.deg, dec=dec*u.deg)
    
    # Satellite track
    ax.plot(coords.ra.deg, coords.dec.deg, 
            transform=ax.get_transform('world'),
            label=sat_name)
        
    # Satellite position points
    ax.scatter(coords.ra.deg, coords.dec.deg, 
               transform=ax.get_transform('world'), s=6)
    
    # Start and end labels
    times = [pos[2] for pos in satellites[sat_name]]
    if coords.ra.deg[0] < coords.ra.deg[-1]:
        ax.text(coords.ra.deg[0], coords.dec.deg[0], f'{sat_name}', 
                transform=ax.get_transform('world'), fontsize="6")  
    else:
        ax.text(coords.ra.deg[-1], coords.dec.deg[-1], f'{sat_name}', 
            transform=ax.get_transform('world'), fontsize="6")

ax.set_aspect('equal')
ax.legend(bbox_to_anchor=(0.95, 1), loc='upper left', fontsize="6")
ax.set_xlabel('Right Ascension')
ax.invert_xaxis()
ax.set_ylabel('Declination')
ax.set_title(f'Satellite Passes at {start_time_jd} (duration {duration:.1f})')
ax.grid(color='lightgray', linestyle='--')

# %% [markdown]
# ### Filter for Starlink Satellites

# %%
telemetry1_filtrado = telemetry1[telemetry1['EXPNUM'].isin(streaks_filtradas['expnum'])]

# %%
telemetry1_filtrado
# Out:
#          EXPNUM BAND              TELESCOP OBSERVAT INSTRUME  OBS-LONG  \
# 1849     145434    z  CTIO 4.0-m telescope     CTIO    DECam   70.8149
# 1856     145505    r  CTIO 4.0-m telescope     CTIO    DECam   70.8149
# 1866     145555    i  CTIO 4.0-m telescope     CTIO    DECam   70.8149
# 1867     145558    i  CTIO 4.0-m telescope     CTIO    DECam   70.8149
# 1868     145559    i  CTIO 4.0-m telescope     CTIO    DECam   70.8149
# ...         ...  ...                   ...      ...      ...       ...
# 504509  1223518    g  CTIO 4.0-m telescope     CTIO    DECam   70.8149
# 504511  1223520    g  CTIO 4.0-m telescope     CTIO    DECam   70.8149
# 504519  1223528    g  CTIO 4.0-m telescope     CTIO    DECam   70.8149
# 504523  1223532    g  CTIO 4.0-m telescope     CTIO    DECam   70.8149
# 504524  1223533    g  CTIO 4.0-m telescope     CTIO    DECam   70.8149
#
#         OBS-LAT  OBS-ELEV  TELEQUIN TIMESYS                    DATE-OBS  \
# 1849   -30.1661      2215      2000     UTC  2012-11-02 04:53:58.963709
# 1856   -30.1661      2215      2000     UTC  2012-11-02 06:18:03.596634
# 1866   -30.1661      2215      2000     UTC  2012-11-02 07:25:16.269456
# 1867   -30.1661      2215      2000     UTC  2012-11-02 07:32:27.251025
# 1868   -30.1661      2215      2000     UTC  2012-11-02 07:34:26.345592
# ...         ...       ...       ...     ...                         ...
# 504509 -30.1661      2215      2000     UTC  2023-07-21 04:02:44.144925
# 504511 -30.1661      2215      2000     UTC  2023-07-21 04:07:18.281902
# 504519 -30.1661      2215      2000     UTC  2023-07-21 04:25:07.161563
# 504523 -30.1661      2215      2000     UTC  2023-07-21 04:33:18.720174
# 504524 -30.1661      2215      2000     UTC  2023-07-21 04:35:19.212277
#
#                TIME-OBS  DARKTIME  EXPTIME            RA            DEC  \
# 1849    04:53:58.963709   31.1660     30.0  00:03:06.361  -29:47:35.696
# 1856    06:18:03.596634   61.1374     60.0  02:24:27.068  -04:16:03.299
# 1866    07:25:16.269456   31.0896     30.0  04:34:13.969   15:11:05.500
# 1867    07:32:27.251025   91.0933     90.0  04:34:13.530   15:11:02.098
# 1868    07:34:26.345592   91.1038     90.0  04:35:39.350   14:51:01.199
# ...                 ...       ...      ...           ...            ...
# 504509  04:02:44.144925   91.1284     90.0  20:12:31.741  -01:22:56.798
# 504511  04:07:18.281902   91.0861     90.0  20:41:41.381  -07:41:56.699
# 504519  04:25:07.161563   91.1412     90.0  21:22:27.278  -20:05:40.600
# 504523  04:33:18.720174   91.0856     90.0  21:32:30.502  -21:38:18.200
# 504524  04:35:19.212277   91.1041     90.0  21:29:40.132  -20:06:01.501
#
#               AZ     ZD
# 1849    259.1000  37.55
# 1856    307.0800  37.89
# 1866    341.6200  47.11
# 1867    339.3600  47.63
# 1868    339.0600  47.36
# ...          ...    ...
# 504509   28.9529  32.15
# 504511   45.5025  29.97
# 504519   73.4940  26.26
# 504523   77.0527  25.96
# 504524   72.7274  25.63
#
# [36287 rows x 18 columns]

# %%
streaks_filtradas
# Out:
#                                      filename  rnum        ra_1        ra_2  \
# 0       D00145425_g_c03_r4148p01_hstreak.fits     3    1.159330    1.160919
# 1       D00145425_g_c06_r4148p01_hstreak.fits     1    0.986677    0.986711
# 2       D00145425_g_c09_r4148p01_hstreak.fits     1    0.452852    0.452942
# 3       D00145425_g_c15_r4148p01_hstreak.fits     1    0.286716    0.286812
# 4       D00145425_g_c16_r4148p01_hstreak.fits     1    0.985852    0.987446
# ...                                       ...   ...         ...         ...
# 879102  D01223533_g_c21_r6224p01_hstreak.fits     1  322.350759  322.367974
# 879103  D01223533_g_c27_r6224p01_hstreak.fits     1  321.914442  321.929370
# 879104  D01223533_g_c33_r6224p01_hstreak.fits     2  321.914515  321.920861
# 879105  D01223533_g_c44_r6224p01_hstreak.fits     1  323.071804  323.087515
# 879106  D01223533_g_c54_r6224p01_hstreak.fits     1  322.679468  322.691395
#
#               ra_3        ra_4      dec_1      dec_2      dec_3      dec_4  \
# 0         1.164310    1.162720 -28.724241 -28.724212 -28.857155 -28.857183
# 1         0.644209    0.644186 -29.032018 -29.034283 -29.037208 -29.034944
# 2         0.109842    0.109782 -29.193042 -29.199694 -29.203265 -29.196615
# 3         0.630816    0.630741 -29.363308 -29.358405 -29.362739 -29.367644
# 4         0.987211    0.985615 -29.216748 -29.216752 -29.366385 -29.366381
# ...            ...         ...        ...        ...        ...        ...
# 879102  322.430509  322.413294 -19.778872 -19.762994 -19.822898 -19.838787
# 879103  322.039930  322.024991 -19.992600 -19.979549 -20.091439 -20.104500
# 879104  321.868432  321.862089 -20.207886 -20.214118 -20.261253 -20.255020
# 879105  323.208026  323.192338 -20.367516 -20.345896 -20.422967 -20.444584
# 879106  322.589240  322.577308 -20.592385 -20.603303 -20.700661 -20.689741
#
#          expnum  ccdnum band
# 0        145425       3    g
# 1        145425       6    g
# 2        145425       9    g
# 3        145425      15    g
# 4        145425      16    g
# ...         ...     ...  ...
# 879102  1223533      21    g
# 879103  1223533      27    g
# 879104  1223533      33    g
# 879105  1223533      44    g
# 879106  1223533      54    g
#
# [532326 rows x 13 columns]

# %%
#expnumtry = telemetry1_filtrado['EXPNUM'].unique()  # Usaria toooooodos los datos :p
expnumtry = telemetry1_filtrado['EXPNUM'].drop_duplicates().sample(20, random_state=42) # Random exposures

# %%
site = EarthLocation.of_site('ctio')
#lat, lon, elev = site.lat.value, site.lon.value, site.height.value

# %%
# Contenedores de resultados
expnum_starlink   = []   # exposures que tuvieron al menos 1 STARLINK
satmap_starlink   = []   # lista de nombres Starlink para cada exposure
satmap_completo   = {}  
todos_satelites = {} 
starlinks_en_exp = []

# %%
for exp in tqdm(expnumtry, desc="Buscando STARLINKs"):
    fila = telemetry1_filtrado[telemetry1_filtrado['EXPNUM'] == exp].iloc[0]

    try:
        ra = fila['RA']
        dec = fila['DEC']
        lat = fila ['OBS-LAT']
        lon = fila['OBS-LONG']
        elev = fila['OBS-ELEV']
        exptime = fila['EXPTIME']
        timeobs = fila['TIME-OBS']
        dateobs = fila['DATE-OBS']

        # Conversión de coordenadas y fecha
        coord = SkyCoord(ra=ra, dec=dec, unit='deg')
        jd = Time(dateobs).jd
        ra_c, dec_c = coord.ra.value, coord.dec.value

        # URL para la API
        url = f"https://dev.satchecker.cps.iau.noirlab.edu/fov/satellite-passes/?latitude={latitude}&longitude={longitude}&elevation={elevation}&start_time_jd={start_time_jd}&duration={duration}&ra={ra_center}&dec={dec_center}&fov_radius={fov_radius}&group_by=satellite"
        response = requests.get(url, timeout=60)
        response.raise_for_status()
        data = response.json()['data']['satellites']            
        
        # Guardar todos los satélites si quieres
        todos_satelites[exp] = list(data.keys())

        # Filtrar Starlink
        starlinks = [sat for sat in data if 'COSMOS' in sat.upper()]  # It was hard to find STARLINKs in a small sample, so I tried with COSMOS instead, they seem more common
        if starlinks:
            expnum_starlink.append(exp)
            starlinks_en_exp.append(starlinks)

    except Exception as e:
        print(f"⚠️ Error en expnum {exp}: {e}")
        continue

# Crear DataFrame con resultados
df_starlink = pd.DataFrame({
    'EXPNUM': expnum_starlink,
    'starlinks': starlinks_en_exp
})

# Vista rápida
print(df_starlink.head())
# Out:
# Buscando STARLINKs: 100%|██████████████████████████████████████████████████████████████| 20/20 [02:52<00:00,  8.64s/it]
#     EXPNUM                                          starlinks
# 0   946224  [COSMOS 1275 DEB (13485), COSMOS 158 (2801), C...
# 1   157334  [COSMOS 1275 DEB (13485), COSMOS 158 (2801), C...
# 2  1025163  [COSMOS 1275 DEB (13485), COSMOS 158 (2801), C...
# 3  1215959  [COSMOS 1275 DEB (13485), COSMOS 158 (2801), C...
# 4  1058234  [COSMOS 1275 DEB (13485), COSMOS 158 (2801), C...

# %% [markdown]
# Exposure 1215959  have two starlinks...

# %%
df_starlink
# Out:
#      EXPNUM                                          starlinks
# 0    946224  [COSMOS 1275 DEB (13485), COSMOS 158 (2801), C...
# 1    157334  [COSMOS 1275 DEB (13485), COSMOS 158 (2801), C...
# 2   1025163  [COSMOS 1275 DEB (13485), COSMOS 158 (2801), C...
# 3   1215959  [COSMOS 1275 DEB (13485), COSMOS 158 (2801), C...
# 4   1058234  [COSMOS 1275 DEB (13485), COSMOS 158 (2801), C...
# 5   1215919  [COSMOS 1275 DEB (13485), COSMOS 158 (2801), C...
# 6    970728  [COSMOS 1275 DEB (13485), COSMOS 158 (2801), C...
# 7    250715  [COSMOS 1275 DEB (13485), COSMOS 158 (2801), C...
# 8   1019973  [COSMOS 1275 DEB (13485), COSMOS 158 (2801), C...
# 9   1011967  [COSMOS 1275 DEB (13485), COSMOS 158 (2801), C...
# 10   659213  [COSMOS 1275 DEB (13485), COSMOS 158 (2801), C...
# 11  1110001  [COSMOS 1275 DEB (13485), COSMOS 158 (2801), C...
# 12   706855  [COSMOS 1275 DEB (13485), COSMOS 158 (2801), C...
# 13  1171116  [COSMOS 1275 DEB (13485), COSMOS 158 (2801), C...
# 14   193305  [COSMOS 1275 DEB (13485), COSMOS 158 (2801), C...
# 15   286630  [COSMOS 1275 DEB (13485), COSMOS 158 (2801), C...
# 16   545438  [COSMOS 1275 DEB (13485), COSMOS 158 (2801), C...
# 17   793746  [COSMOS 1275 DEB (13485), COSMOS 158 (2801), C...
# 18  1132872  [COSMOS 1275 DEB (13485), COSMOS 158 (2801), C...
# 19   358063  [COSMOS 1275 DEB (13485), COSMOS 158 (2801), C...

# %%
todos_satelites
# Out:
# {946224: ['COSMOS 1275 DEB (13485)',
#   'COSMOS 158 (2801)',
#   'COSMOS 2251 DEB (37303)',
#   'COSMOS 2353 (25364)',
#   'DELTA 1 DEB (17764)',
#   'DELTA 1 DEB (21387)',
#   'DELTA 1 DEB (7044)',
#   'FENGYUN 1C DEB (29873)',
#   'FENGYUN 1C DEB (31675)',
#   'NIMBUS 2 DEB (28203)',
#   'SL-24 R/B (28811)',
#   'THOR ABLESTAR DEB (479)',
#   'THORAD DELTA 1 DEB (8562)',
#   'THORAD DELTA 1 R/B (7532)',
#   'TIANHUI 1-03 (40988)'],
#  157334: ['COSMOS 1275 DEB (13485)',
#   'COSMOS 158 (2801)',
#   'COSMOS 2251 DEB (37303)',
#   'COSMOS 2353 (25364)',
#   'DELTA 1 DEB (17764)',
#   'DELTA 1 DEB (21387)',
#   'DELTA 1 DEB (7044)',
#   'FENGYUN 1C DEB (29873)',
#   'FENGYUN 1C DEB (31675)',
#   'NIMBUS 2 DEB (28203)',
#   'SL-24 R/B (28811)',
#   'THOR ABLESTAR DEB (479)',
#   'THORAD DELTA 1 DEB (8562)',
#   'THORAD DELTA 1 R/B (7532)',
#   'TIANHUI 1-03 (40988)'],
#  1025163: ['COSMOS 1275 DEB (13485)',
#   'COSMOS 158 (2801)',
#   'COSMOS 2251 DEB (37303)',
#   'COSMOS 2353 (25364)',
#   'DELTA 1 DEB (17764)',
#   'DELTA 1 DEB (21387)',
#   'DELTA 1 DEB (7044)',
#   'FENGYUN 1C DEB (29873)',
#   'FENGYUN 1C DEB (31675)',
#   'NIMBUS 2 DEB (28203)',
#   'SL-24 R/B (28811)',
#   'THOR ABLESTAR DEB (479)',
#   'THORAD DELTA 1 DEB (8562)',
#   'THORAD DELTA 1 R/B (7532)',
#   'TIANHUI 1-03 (40988)'],
#  1215959: ['COSMOS 1275 DEB (13485)',
#   'COSMOS 158 (2801)',
#   'COSMOS 2251 DEB (37303)',
#   'COSMOS 2353 (25364)',
#   'DELTA 1 DEB (17764)',
#   'DELTA 1 DEB (21387)',
#   'DELTA 1 DEB (7044)',
#   'FENGYUN 1C DEB (29873)',
#   'FENGYUN 1C DEB (31675)',
#   'NIMBUS 2 DEB (28203)',
#   'SL-24 R/B (28811)',
#   'THOR ABLESTAR DEB (479)',
#   'THORAD DELTA 1 DEB (8562)',
#   'THORAD DELTA 1 R/B (7532)',
#   'TIANHUI 1-03 (40988)'],
#  1058234: ['COSMOS 1275 DEB (13485)',
#   'COSMOS 158 (2801)',
#   'COSMOS 2251 DEB (37303)',
#   'COSMOS 2353 (25364)',
#   'DELTA 1 DEB (17764)',
#   'DELTA 1 DEB (21387)',
#   'DELTA 1 DEB (7044)',
#   'FENGYUN 1C DEB (29873)',
#   'FENGYUN 1C DEB (31675)',
#   'NIMBUS 2 DEB (28203)',
#   'SL-24 R/B (28811)',
#   'THOR ABLESTAR DEB (479)',
#   'THORAD DELTA 1 DEB (8562)',
#   'THORAD DELTA 1 R/B (7532)',
#   'TIANHUI 1-03 (40988)'],
#  1215919: ['COSMOS 1275 DEB (13485)',
#   'COSMOS 158 (2801)',
#   'COSMOS 2251 DEB (37303)',
#   'COSMOS 2353 (25364)',
#   'DELTA 1 DEB (17764)',
#   'DELTA 1 DEB (21387)',
#   'DELTA 1 DEB (7044)',
#   'FENGYUN 1C DEB (29873)',
#   'FENGYUN 1C DEB (31675)',
#   'NIMBUS 2 DEB (28203)',
#   'SL-24 R/B (28811)',
#   'THOR ABLESTAR DEB (479)',
#   'THORAD DELTA 1 DEB (8562)',
#   'THORAD DELTA 1 R/B (7532)',
#   'TIANHUI 1-03 (40988)'],
#  970728: ['COSMOS 1275 DEB (13485)',
#   'COSMOS 158 (2801)',
#   'COSMOS 2251 DEB (37303)',
#   'COSMOS 2353 (25364)',
#   'DELTA 1 DEB (17764)',
#   'DELTA 1 DEB (21387)',
#   'DELTA 1 DEB (7044)',
#   'FENGYUN 1C DEB (29873)',
#   'FENGYUN 1C DEB (31675)',
#   'NIMBUS 2 DEB (28203)',
#   'SL-24 R/B (28811)',
#   'THOR ABLESTAR DEB (479)',
#   'THORAD DELTA 1 DEB (8562)',
#   'THORAD DELTA 1 R/B (7532)',
#   'TIANHUI 1-03 (40988)'],
#  250715: ['COSMOS 1275 DEB (13485)',
#   'COSMOS 158 (2801)',
#   'COSMOS 2251 DEB (37303)',
#   'COSMOS 2353 (25364)',
#   'DELTA 1 DEB (17764)',
#   'DELTA 1 DEB (21387)',
#   'DELTA 1 DEB (7044)',
#   'FENGYUN 1C DEB (29873)',
#   'FENGYUN 1C DEB (31675)',
#   'NIMBUS 2 DEB (28203)',
#   'SL-24 R/B (28811)',
#   'THOR ABLESTAR DEB (479)',
#   'THORAD DELTA 1 DEB (8562)',
#   'THORAD DELTA 1 R/B (7532)',
#   'TIANHUI 1-03 (40988)'],
#  1019973: ['COSMOS 1275 DEB (13485)',
#   'COSMOS 158 (2801)',
#   'COSMOS 2251 DEB (37303)',
#   'COSMOS 2353 (25364)',
#   'DELTA 1 DEB (17764)',
#   'DELTA 1 DEB (21387)',
#   'DELTA 1 DEB (7044)',
#   'FENGYUN 1C DEB (29873)',
#   'FENGYUN 1C DEB (31675)',
#   'NIMBUS 2 DEB (28203)',
#   'SL-24 R/B (28811)',
#   'THOR ABLESTAR DEB (479)',
#   'THORAD DELTA 1 DEB (8562)',
#   'THORAD DELTA 1 R/B (7532)',
#   'TIANHUI 1-03 (40988)'],
#  1011967: ['COSMOS 1275 DEB (13485)',
#   'COSMOS 158 (2801)',
#   'COSMOS 2251 DEB (37303)',
#   'COSMOS 2353 (25364)',
#   'DELTA 1 DEB (17764)',
#   'DELTA 1 DEB (21387)',
#   'DELTA 1 DEB (7044)',
#   'FENGYUN 1C DEB (29873)',
#   'FENGYUN 1C DEB (31675)',
#   'NIMBUS 2 DEB (28203)',
#   'SL-24 R/B (28811)',
#   'THOR ABLESTAR DEB (479)',
#   'THORAD DELTA 1 DEB (8562)',
#   'THORAD DELTA 1 R/B (7532)',
#   'TIANHUI 1-03 (40988)'],
#  659213: ['COSMOS 1275 DEB (13485)',
#   'COSMOS 158 (2801)',
#   'COSMOS 2251 DEB (37303)',
#   'COSMOS 2353 (25364)',
#   'DELTA 1 DEB (17764)',
#   'DELTA 1 DEB (21387)',
#   'DELTA 1 DEB (7044)',
#   'FENGYUN 1C DEB (29873)',
#   'FENGYUN 1C DEB (31675)',
#   'NIMBUS 2 DEB (28203)',
#   'SL-24 R/B (28811)',
#   'THOR ABLESTAR DEB (479)',
#   'THORAD DELTA 1 DEB (8562)',
#   'THORAD DELTA 1 R/B (7532)',
#   'TIANHUI 1-03 (40988)'],
#  1110001: ['COSMOS 1275 DEB (13485)',
#   'COSMOS 158 (2801)',
#   'COSMOS 2251 DEB (37303)',
#   'COSMOS 2353 (25364)',
#   'DELTA 1 DEB (17764)',
#   'DELTA 1 DEB (21387)',
#   'DELTA 1 DEB (7044)',
#   'FENGYUN 1C DEB (29873)',
#   'FENGYUN 1C DEB (31675)',
#   'NIMBUS 2 DEB (28203)',
#   'SL-24 R/B (28811)',
#   'THOR ABLESTAR DEB (479)',
#   'THORAD DELTA 1 DEB (8562)',
#   'THORAD DELTA 1 R/B (7532)',
#   'TIANHUI 1-03 (40988)'],
#  706855: ['COSMOS 1275 DEB (13485)',
#   'COSMOS 158 (2801)',
#   'COSMOS 2251 DEB (37303)',
#   'COSMOS 2353 (25364)',
#   'DELTA 1 DEB (17764)',
#   'DELTA 1 DEB (21387)',
#   'DELTA 1 DEB (7044)',
#   'FENGYUN 1C DEB (29873)',
#   'FENGYUN 1C DEB (31675)',
#   'NIMBUS 2 DEB (28203)',
#   'SL-24 R/B (28811)',
#   'THOR ABLESTAR DEB (479)',
#   'THORAD DELTA 1 DEB (8562)',
#   'THORAD DELTA 1 R/B (7532)',
#   'TIANHUI 1-03 (40988)'],
#  1171116: ['COSMOS 1275 DEB (13485)',
#   'COSMOS 158 (2801)',
#   'COSMOS 2251 DEB (37303)',
#   'COSMOS 2353 (25364)',
#   'DELTA 1 DEB (17764)',
#   'DELTA 1 DEB (21387)',
#   'DELTA 1 DEB (7044)',
#   'FENGYUN 1C DEB (29873)',
#   'FENGYUN 1C DEB (31675)',
#   'NIMBUS 2 DEB (28203)',
#   'SL-24 R/B (28811)',
#   'THOR ABLESTAR DEB (479)',
#   'THORAD DELTA 1 DEB (8562)',
#   'THORAD DELTA 1 R/B (7532)',
#   'TIANHUI 1-03 (40988)'],
#  193305: ['COSMOS 1275 DEB (13485)',
#   'COSMOS 158 (2801)',
#   'COSMOS 2251 DEB (37303)',
#   'COSMOS 2353 (25364)',
#   'DELTA 1 DEB (17764)',
#   'DELTA 1 DEB (21387)',
#   'DELTA 1 DEB (7044)',
#   'FENGYUN 1C DEB (29873)',
#   'FENGYUN 1C DEB (31675)',
#   'NIMBUS 2 DEB (28203)',
#   'SL-24 R/B (28811)',
#   'THOR ABLESTAR DEB (479)',
#   'THORAD DELTA 1 DEB (8562)',
#   'THORAD DELTA 1 R/B (7532)',
#   'TIANHUI 1-03 (40988)'],
#  286630: ['COSMOS 1275 DEB (13485)',
#   'COSMOS 158 (2801)',
#   'COSMOS 2251 DEB (37303)',
#   'COSMOS 2353 (25364)',
#   'DELTA 1 DEB (17764)',
#   'DELTA 1 DEB (21387)',
#   'DELTA 1 DEB (7044)',
#   'FENGYUN 1C DEB (29873)',
#   'FENGYUN 1C DEB (31675)',
#   'NIMBUS 2 DEB (28203)',
#   'SL-24 R/B (28811)',
#   'THOR ABLESTAR DEB (479)',
#   'THORAD DELTA 1 DEB (8562)',
#   'THORAD DELTA 1 R/B (7532)',
#   'TIANHUI 1-03 (40988)'],
#  545438: ['COSMOS 1275 DEB (13485)',
#   'COSMOS 158 (2801)',
#   'COSMOS 2251 DEB (37303)',
#   'COSMOS 2353 (25364)',
#   'DELTA 1 DEB (17764)',
#   'DELTA 1 DEB (21387)',
#   'DELTA 1 DEB (7044)',
#   'FENGYUN 1C DEB (29873)',
#   'FENGYUN 1C DEB (31675)',
#   'NIMBUS 2 DEB (28203)',
#   'SL-24 R/B (28811)',
#   'THOR ABLESTAR DEB (479)',
#   'THORAD DELTA 1 DEB (8562)',
#   'THORAD DELTA 1 R/B (7532)',
#   'TIANHUI 1-03 (40988)'],
#  793746: ['COSMOS 1275 DEB (13485)',
#   'COSMOS 158 (2801)',
#   'COSMOS 2251 DEB (37303)',
#   'COSMOS 2353 (25364)',
#   'DELTA 1 DEB (17764)',
#   'DELTA 1 DEB (21387)',
#   'DELTA 1 DEB (7044)',
#   'FENGYUN 1C DEB (29873)',
#   'FENGYUN 1C DEB (31675)',
#   'NIMBUS 2 DEB (28203)',
#   'SL-24 R/B (28811)',
#   'THOR ABLESTAR DEB (479)',
#   'THORAD DELTA 1 DEB (8562)',
#   'THORAD DELTA 1 R/B (7532)',
#   'TIANHUI 1-03 (40988)'],
#  1132872: ['COSMOS 1275 DEB (13485)',
#   'COSMOS 158 (2801)',
#   'COSMOS 2251 DEB (37303)',
#   'COSMOS 2353 (25364)',
#   'DELTA 1 DEB (17764)',
#   'DELTA 1 DEB (21387)',
#   'DELTA 1 DEB (7044)',
#   'FENGYUN 1C DEB (29873)',
#   'FENGYUN 1C DEB (31675)',
#   'NIMBUS 2 DEB (28203)',
#   'SL-24 R/B (28811)',
#   'THOR ABLESTAR DEB (479)',
#   'THORAD DELTA 1 DEB (8562)',
#   'THORAD DELTA 1 R/B (7532)',
#   'TIANHUI 1-03 (40988)'],
#  358063: ['COSMOS 1275 DEB (13485)',
#   'COSMOS 158 (2801)',
#   'COSMOS 2251 DEB (37303)',
#   'COSMOS 2353 (25364)',
#   'DELTA 1 DEB (17764)',
#   'DELTA 1 DEB (21387)',
#   'DELTA 1 DEB (7044)',
#   'FENGYUN 1C DEB (29873)',
#   'FENGYUN 1C DEB (31675)',
#   'NIMBUS 2 DEB (28203)',
#   'SL-24 R/B (28811)',
#   'THOR ABLESTAR DEB (479)',
#   'THORAD DELTA 1 DEB (8562)',
#   'THORAD DELTA 1 R/B (7532)',
#   'TIANHUI 1-03 (40988)']}
